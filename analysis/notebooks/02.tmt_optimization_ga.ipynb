# %% [markdown]
# # Genetic Algorithm Optimization for Relay Coordination (IEC)
#
# This notebook implements a faithful adaptation of the MATLAB GA (Chu & Beasley style) used for relay setting optimization. It reads independent relay pairs, groups by scenario, runs GA per scenario, writes optimized values, updates pairs, and generates figures and a text report. All outputs are saved under `results/` and `data/processed/`.

# %%
# %% Imports and Constants (IEC / GA)
import os, json, math, random
from datetime import datetime, timezone
from pathlib import Path

# Plotting for inline diagnostics (optional)
import matplotlib
matplotlib.use("Agg")  # switch to inline later if needed
import matplotlib.pyplot as plt

# =============== CONSTANTS (aligned with MATLAB) ===============
K = 0.14
N = 0.02

CTI = 0.20
MIN_TDS = 0.05
MAX_TDS = 0.8
MIN_PICKUP = 0.05
MAX_PICKUP_FACTOR = 0.6
MAX_TIME = 10.0

# Heuristic placeholders (kept for signature compatibility)
MAX_ITERATIONS = 500
MIN_ALLOWED_INDIVIDUAL_MT = -0.009
CONVERGENCE_THRESHOLD_TMT = 0.005
STAGNATION_LIMIT = 25

# GA (Chu & Beasley) — matched to MATLAB
GA_Ni = 80
GA_iterno = 50000
GA_maxGen = 50000
GA_nMut = 2

# %%
# %% Utilities (paths, parsing, IEC time)

def _paths():
    nb_dir = Path.cwd()
    # Robust project root detection for portability
    if nb_dir.name == 'notebooks' and nb_dir.parent.name == 'analysis':
        project_root = nb_dir.parent.parent  # .../AutoDOC-MG
    elif nb_dir.name == 'analysis':
        project_root = nb_dir.parent
    else:
        project_root = nb_dir if (nb_dir / 'data').exists() else nb_dir.parent

    in_dir   = project_root / "data" / "raw"
    out_dir  = project_root / "data" / "processed"
    res_dir  = project_root / "results"
    # Prefer processed scenario_1 pairs exported by analysis notebook
    in_file  = out_dir / "automation_results_scenario_1.json"
    opt_file = out_dir / "optimized_relay_values_scenario_1_GA.json"
    pairs_out= out_dir / "automation_results_scenario_1_optimized.json"
    fig_dir  = res_dir / "figures"
    rep_dir  = res_dir / "reports"
    return project_root, in_file, opt_file, pairs_out, fig_dir, rep_dir


def get_numeric_field(dct, names):
    for n in names:
        if n in dct:
            try:
                return float(dct[n])
            except Exception:
                pass
    return None


def store_initial_setting(initial, relay_info):
    name = str(relay_info.get("relay", "")).strip()
    if not name or name in initial:
        return
    tds = get_numeric_field(relay_info, ["TDS", "tds"])
    pu  = get_numeric_field(relay_info, ["pick_up", "pickup"])
    if tds is not None or pu is not None:
        initial[name] = {"TDS_initial": tds, "pickup_initial": pu}


def group_data_by_scenario(data_array):
    scenario_map = {}
    for entry in data_array:
        sid = entry.get("scenario_id")
        m   = entry.get("main_relay"); b = entry.get("backup_relay")
        if not sid or not m or not b:
            continue
        mname = str(m.get("relay", "")).strip()
        bname = str(b.get("relay", "")).strip()
        if not mname or not bname:
            continue
        im = get_numeric_field(m, ["Ishc", "I_shc", "Isc", "fault_current"])
        ib = get_numeric_field(b, ["Ishc", "I_shc", "Isc", "fault_current"])
        if not im or not ib or im <= 0 or ib <= 0:
            continue
        if sid not in scenario_map:
            scenario_map[sid] = {"pairs": [], "relays": [], "initial_settings": {}}
        scenario_map[sid]["pairs"].append({
            "main_relay": mname, "backup_relay": bname,
            "Ishc_main": im, "Ishc_backup": ib
        })
        if mname not in scenario_map[sid]["relays"]:
            scenario_map[sid]["relays"].append(mname)
        if bname not in scenario_map[sid]["relays"]:
            scenario_map[sid]["relays"].append(bname)
        store_initial_setting(scenario_map[sid]["initial_settings"], m)
        store_initial_setting(scenario_map[sid]["initial_settings"], b)
    return scenario_map


def time_iec(I, PU, TDS):
    if I is None or PU is None or TDS is None:
        return float("nan")
    try:
        M = I/PU
        denom = (M**N) - 1.0
        if denom <= 0:
            return float("inf")
        return (K*TDS)/denom
    except Exception:
        return float("nan")

# %%
# %% Genetic Algorithm (Chu & Beasley style)

def Genetico(scenarioID, scenarioData,
             K_, N_, CTI_,
             MIN_TDS_, MAX_TDS_, MIN_PICKUP_, MAX_PICKUP_FACTOR_, MAX_TIME_,
             *_unused):
    pairs = scenarioData["pairs"]
    relays= [r for r in scenarioData["relays"] if str(r).strip()]
    nR = len(relays)
    if nR == 0:
        print(f'Scenario "{scenarioID}" has no valid relays.')
        return {}

    idx = {relays[i]: i for i in range(nR)}

    # Min Isc per relay
    IscMin = [float("inf")]*nR
    for p in pairs:
        IscMin[idx[p["main_relay"]]]   = min(IscMin[idx[p["main_relay"]]],   p["Ishc_main"])
        IscMin[idx[p["backup_relay"]]] = min(IscMin[idx[p["backup_relay"]]], p["Ishc_backup"])

    # Bounds
    xmin = ([MIN_TDS_]*nR) + ([MIN_PICKUP_]*nR)
    xmax = ([MAX_TDS_]*nR) + ([MAX_PICKUP_FACTOR_*IscMin[i] for i in range(nR)])
    Nv   = 2*nR

    def relay_time(I, PU, TDS):
        if I <= PU:
            return MAX_TIME_*10.0  # penalty as in MATLAB
        t = TDS * (K_ / ((I/PU)**N_ - 1.0))
        return min(max(t,0.0), MAX_TIME_*10.0)

    def fitness(ind):
        tds = ind[:nR]; pu = ind[nR:]
        tmt = 0.0
        for p in pairs:
            mi = idx[p["main_relay"]]; bi = idx[p["backup_relay"]]
            tM = relay_time(p["Ishc_main"],   pu[mi], tds[mi])
            tB = relay_time(p["Ishc_backup"], pu[bi], tds[bi])
            if (tB - tM) < CTI_:
                tmt += (CTI_ - (tB - tM))
            if tM > MAX_TIME_:
                tmt += (tM - MAX_TIME_)
        return tmt

    # Initial population
    X = []
    for _ in range(GA_Ni):
        ind = [xmin[j] + random.random()*(xmax[j]-xmin[j]) for j in range(Nv)]
        X.append(ind + [fitness(ind)])
    X.sort(key=lambda r: r[Nv])
    X_best = X[0][:]
    print(f'    GA: generation 0  – TMT = {X_best[Nv]:.6f}')

    stall = 0
    for gen in range(1, GA_maxGen+1):
        s1, s2 = random.sample(range(GA_Ni), 2)
        P1 = X[s1][:Nv]; P2 = X[s2][:Nv]
        cp = random.randint(1, Nv-1)
        H1 = P1[:cp] + P2[cp:]
        H2 = P2[:cp] + P1[cp:]

        def mutate(ch):
            for m in random.sample(range(Nv), GA_nMut):
                ch[m] = xmin[m] + random.random()*(xmax[m]-xmin[m])
            return ch
        H1 = mutate(H1); H2 = mutate(H2)
        f1 = fitness(H1); f2 = fitness(H2)

        # Replacement (best of two children) if improves worst and not duplicate
        cand = [(H1,f1),(H2,f2)]
        cand.sort(key=lambda t: t[1])
        child, fchild = cand[0]
        if fchild < X[-1][Nv]:
            duplicate = any(all(abs(child[j]-X[k][j]) < 1e-12 for j in range(Nv)) for k in range(GA_Ni))
            if not duplicate:
                X[-1] = child + [fchild]

        X.sort(key=lambda r: r[Nv])
        if X[0][Nv] < X_best[Nv]:
            X_best = X[0][:]
            stall = 0
        else:
            stall += 1

        if gen % 50 == 0:
            print(f'    GA: generation {gen} – TMT = {X_best[Nv]:.6f}')
        if X_best[Nv] == 0.0:
            break
        if stall >= GA_iterno:
            print(f'    GA: stagnation ({GA_iterno} gen without improvement).')
            break

    print(f'    GA finished. Generations: {gen}  – Best TMT = {X_best[Nv]:.6f}')
    best = X_best[:Nv]; TDSbest = best[:nR]; PUbest = best[nR:]
    optimized = { relays[r]: {"TDS": round(TDSbest[r],5), "pickup": round(PUbest[r],5)} for r in range(nR) }
    return optimized

# %%
# %% Plotting and Text Report (matplotlib, non-blocking)

def plot_and_report_from_pairs(pairs_out_path, CTI_val, maxPairs, fig_dir, rep_dir, show=False):
    import matplotlib
    if not show:
        matplotlib.use("Agg")
    import matplotlib.pyplot as plt

    Path(fig_dir).mkdir(parents=True, exist_ok=True)
    Path(rep_dir).mkdir(parents=True, exist_ok=True)
    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    figureFile = Path(fig_dir) / f"MT_TDS_Pickup_optimized_{ts}.png"
    reportFile = Path(rep_dir) / f"results_MT_optimized_{ts}.txt"

    with open(pairs_out_path, "r", encoding="utf-8") as f:
        S = json.load(f)
    if not isinstance(S, list) or not S:
        raise RuntimeError("Empty or invalid JSON format (pairs).")

    rows = []
    for item in S:
        if "main_relay" not in item or "backup_relay" not in item:
            continue
        m = item["main_relay"]; b = item["backup_relay"]
        need = ("relay","TDS","pick_up","Time_out")
        if not all(k in m for k in need) or not all(k in b for k in need):
            continue
        pairID = f"{m['relay']}-{b['relay']}"
        dt = (b["Time_out"] - m["Time_out"]) - CTI_val
        MT = dt if dt < 0 else 0.0
        rows.append({
            "pairID": pairID,
            "TDSm": m["TDS"], "TDSb": b["TDS"],
            "PUm": m["pick_up"], "PUb": b["pick_up"],
            "TimeOutM": m["Time_out"], "TimeOutB": b["Time_out"],
            "MT": MT
        })
    if not rows:
        raise RuntimeError("No valid pairs to analyze.")

    rows.sort(key=lambda r: r["MT"])
    Tplot = rows[:min(maxPairs, len(rows))]
    xNums  = list(range(1, len(Tplot)+1))
    labels = [r["pairID"] for r in Tplot]

    f = plt.figure(figsize=(14, 8), facecolor="w")
    f.suptitle("Relay Coordination", y=0.99)
    gs = f.add_gridspec(2,1, hspace=0.10)

    axA = f.add_subplot(gs[0,0])
    MT_vals = [r["MT"] for r in Tplot]
    bars = axA.bar(range(len(Tplot)), MT_vals)
    for i, mt in enumerate(MT_vals):
        bars[i].set_color((0.20,0.60,0.20) if mt == 0 else (0.85,0.20,0.20))
    axA.axhline(0, color="k", linestyle="--")
    axA.text(0.01, 0.02, "CTI satisfied", transform=axA.transAxes, ha="left", fontstyle="italic")
    axA.set_ylabel("MT (s)")
    axA.set_title("Coordination Margin")
    axA.grid(True)
    axA.set_xticks([])

    axB = f.add_subplot(gs[1,0]); axB2 = axB.twinx()
    TDSm = [r["TDSm"] for r in Tplot]; TDSb = [r["TDSb"] for r in Tplot]
    PUm  = [r["PUm"]  for r in Tplot]; PUb  = [r["PUb"]  for r in Tplot]
    axB.plot(xNums, TDSm, "^-", linewidth=1.2, markerfacecolor=(0,0.45,0.74))
    axB.plot(xNums, TDSb, "v-", linewidth=1.2, markerfacecolor=(0.85,0.33,0.10))
    axB.set_ylabel("TDS")
    axB2.plot(xNums, PUm, "o--", linewidth=1.2, markerfacecolor="w")
    axB2.plot(xNums, PUb, "s--", linewidth=1.2, markerfacecolor="w")
    axB2.set_ylabel("Pickup (A)")
    axB.set_xticks(xNums); axB.set_xticklabels(labels, rotation=45)
    axB.set_xlabel("Main-Backup pair")
    axB.set_title("Settings TDS (solid) and Pickup (dashed)")
    axB.grid(True); axB.set_xlim(0.5, len(Tplot)+0.5)

    f.savefig(figureFile, dpi=300)
    print(f"Figure saved: {figureFile}")
    if show:
        plt.show()
    plt.close(f)

    coord   = [r["pairID"] for r in Tplot if r["MT"] == 0]
    uncoord = [r["pairID"] for r in Tplot if r["MT"] < 0]
    TMT     = sum(r["MT"] for r in Tplot)
    with open(reportFile, "w", encoding="utf-8") as fid:
        fid.write("RELAY COORDINATION REPORT\n\n")
        fid.write(f"File: {pairs_out_path}\n")
        fid.write(f"Date: {datetime.now()}\n")
        fid.write(f"CTI : {CTI_val:.2f} s\n\n")
        fid.write(f"Analyzed pairs         : {len(Tplot)}\n")
        fid.write(f"Coordinated (MT = 0)   : {len(coord)}\n")
        fid.write(f"Uncoordinated (MT < 0) : {len(uncoord)}\n")
        fid.write(f"Shown TMT              : {TMT:.6f} s\n\n")
        fid.write("--- UNCOORDINATED PAIRS ---\n")
        fid.write("(All coordinated)\n" if not uncoord else "\n".join(uncoord) + "\n")
    print(f"Report saved: {reportFile}")

# %%
# %% Driver: Load, group, optimize, update pairs, report

project_root, in_file, opt_file, pairs_out, fig_dir, rep_dir = _paths()
print(f"Project root: {project_root}")
print(f"Input file : {in_file}")

# Load input
with open(in_file, "r", encoding="utf-8") as f:
    raw = json.load(f)
if not isinstance(raw, list):
    raise TypeError("Input JSON must be a list of objects")
print(f"Loaded {len(raw)} entries from JSON.")

# Group by scenario
scenarioMap = group_data_by_scenario(raw)
scenarioIDs = list(scenarioMap.keys())
if not scenarioIDs:
    raise RuntimeError("No valid scenarios found in input data")
print(f"Found scenarios: {', '.join(scenarioIDs)}")

# Optimize per scenario
allOptimized = {}
for sid in scenarioIDs:
    data = scenarioMap[sid]
    print(f"\n>>> Optimizing scenario: {sid} – Pairs: {len(data['pairs'])}, Relays: {len(data['relays'])}")
    if not data["pairs"]:
        print(f"Scenario '{sid}' with no valid pairs. Skipping…")
        continue
    opt = Genetico(sid, data, K, N, CTI, MIN_TDS, MAX_TDS, MIN_PICKUP, MAX_PICKUP_FACTOR, MAX_TIME,
                   MAX_ITERATIONS, MIN_ALLOWED_INDIVIDUAL_MT, CONVERGENCE_THRESHOLD_TMT, STAGNATION_LIMIT,
                   -CTI*0.75, 1.15, 0.90, 1.05, 0.02, 0.01)
    if opt:
        allOptimized[sid] = opt
        print(f"    Scenario '{sid}' optimized. {len(opt)} relays updated.")
    else:
        print(f"    Optimization produced no results for '{sid}'.")

# Save optimization results
Path(opt_file).parent.mkdir(parents=True, exist_ok=True)
out_list = []
for sid, vals in allOptimized.items():
    out_list.append({
        "scenario_id": sid,
        "timestamp": datetime.now(timezone.utc).strftime("%Y-%m-%dT%H:%M:%S.%fZ"),
        "relay_values": vals
    })
with open(opt_file, "w", encoding="utf-8") as f:
    json.dump(out_list, f, indent=2, ensure_ascii=False)
print(f"\nOptimization results saved to: {opt_file}")

# Update pairs with optimal settings (IEC time)
with open(in_file, "r", encoding="utf-8") as f:
    pairs = json.load(f)
relayVals = out_list[0]["relay_values"] if out_list else {}
opt_map = { name: (vals["pickup"], vals["TDS"]) for name, vals in relayVals.items() }

updated = []
for p in pairs:
    # main
    rn = p["main_relay"]["relay"]
    if rn in opt_map:
        pu, tds = opt_map[rn]
        p["main_relay"]["pick_up"]  = pu
        p["main_relay"]["TDS"]      = tds
        Ishc_m = get_numeric_field(p["main_relay"], ["Ishc","I_shc","Isc","fault_current"])
        p["main_relay"]["Time_out"] = time_iec(Ishc_m, pu, tds)
    # backup
    rn = p["backup_relay"]["relay"]
    if rn in opt_map:
        pu, tds = opt_map[rn]
        p["backup_relay"]["pick_up"]  = pu
        p["backup_relay"]["TDS"]      = tds
        Ishc_b = get_numeric_field(p["backup_relay"], ["Ishc","I_shc","Isc","fault_current"])
        p["backup_relay"]["Time_out"] = time_iec(Ishc_b, pu, tds)
    updated.append(p)

with open(pairs_out, "w", encoding="utf-8") as f:
    json.dump(updated, f, indent=2, ensure_ascii=False)
print(f"✅ Final pairs file created: {pairs_out}")

# Plots + report
plot_and_report_from_pairs(str(pairs_out), CTI, 100, str(fig_dir), str(rep_dir), show=False)
# Out:
# Project root: /Users/gustavo/Documents/Projects/TESIS_UNAL/AutoDOC-MG
# Input file : /Users/gustavo/Documents/Projects/TESIS_UNAL/AutoDOC-MG/data/processed/automation_results_scenario_1.json
# Loaded 100 entries from JSON.
# Found scenarios: scenario_1
#
# >>> Optimizing scenario: scenario_1 – Pairs: 100, Relays: 74
#     GA: generation 0  – TMT = 45.562172
#     GA: generation 50 – TMT = 39.988764
#     GA: generation 100 – TMT = 39.988764
#     GA: generation 150 – TMT = 36.117256
#     GA: generation 200 – TMT = 36.117256
#     GA: generation 250 – TMT = 33.362699
#     GA: generation 300 – TMT = 33.362699
#     GA: generation 350 – TMT = 31.315466
#     GA: generation 400 – TMT = 30.213453
#     GA: generation 450 – TMT = 30.213453
#     GA: generation 500 – TMT = 30.213453
#     GA: generation 550 – TMT = 26.210154
#     GA: generation 600 – TMT = 24.239564
#     GA: generation 650 – TMT = 23.876696
#     GA: generation 700 – TMT = 23.876696
#     GA: generation 750 – TMT = 23.876696
#     GA: generation 800 – TMT = 21.760005
#     GA: generation 850 – TMT = 20.505901
#     GA: generation 900 – TMT = 19.822018
#     GA: generation 950 – TMT = 19.524218
#     GA: generation 1000 – TMT = 17.405341
#     GA: generation 1050 – TMT = 17.405341
#     GA: generation 1100 – TMT = 17.347245
#     GA: generation 1150 – TMT = 16.935351
#     GA: generation 1200 – TMT = 15.712725
#     GA: generation 1250 – TMT = 15.712725
#     GA: generation 1300 – TMT = 14.828071
#     GA: generation 1350 – TMT = 14.828071
#     GA: generation 1400 – TMT = 14.636429
#     GA: generation 1450 – TMT = 14.416770
#     GA: generation 1500 – TMT = 14.416770
#     GA: generation 1550 – TMT = 12.348516
#     GA: generation 1600 – TMT = 12.348516
#     GA: generation 1650 – TMT = 12.107452
#     GA: generation 1700 – TMT = 12.107452
#     GA: generation 1750 – TMT = 12.107452
#     GA: generation 1800 – TMT = 12.107452
#     GA: generation 1850 – TMT = 12.107452
#     GA: generation 1900 – TMT = 11.201541
#     GA: generation 1950 – TMT = 11.201541
#     GA: generation 2000 – TMT = 9.917783
#     GA: generation 2050 – TMT = 9.917783
#     GA: generation 2100 – TMT = 9.917783
#     GA: generation 2150 – TMT = 9.917783
#     GA: generation 2200 – TMT = 9.917783
#     GA: generation 2250 – TMT = 9.917783
#     GA: generation 2300 – TMT = 9.792768
#     GA: generation 2350 – TMT = 9.792768
#     GA: generation 2400 – TMT = 9.788396
#     GA: generation 2450 – TMT = 9.788396
#     GA: generation 2500 – TMT = 9.788396
#     GA: generation 2550 – TMT = 9.316105
#     GA: generation 2600 – TMT = 9.316105
#     GA: generation 2650 – TMT = 8.845844
#     GA: generation 2700 – TMT = 8.845844
#     GA: generation 2750 – TMT = 8.778219
#     GA: generation 2800 – TMT = 8.778219
#     GA: generation 2850 – TMT = 8.575117
#     GA: generation 2900 – TMT = 8.575117
#     GA: generation 2950 – TMT = 8.169193
#     GA: generation 3000 – TMT = 8.169193
#     GA: generation 3050 – TMT = 8.169193
#     GA: generation 3100 – TMT = 8.169193
#     GA: generation 3150 – TMT = 7.330821
#     GA: generation 3200 – TMT = 7.330821
#     GA: generation 3250 – TMT = 7.330821
#     GA: generation 3300 – TMT = 7.330821
#     GA: generation 3350 – TMT = 7.330821
#     GA: generation 3400 – TMT = 7.330821
#     GA: generation 3450 – TMT = 6.809802
#     GA: generation 3500 – TMT = 6.729849
#     GA: generation 3550 – TMT = 6.729849
#     GA: generation 3600 – TMT = 6.729849
#     GA: generation 3650 – TMT = 6.729849
#     GA: generation 3700 – TMT = 6.729849
#     GA: generation 3750 – TMT = 6.487918
#     GA: generation 3800 – TMT = 6.487918
#     GA: generation 3850 – TMT = 6.487918
#     GA: generation 3900 – TMT = 6.487918
#     GA: generation 3950 – TMT = 6.403446
#     GA: generation 4000 – TMT = 6.398919
#     GA: generation 4050 – TMT = 6.064962
#     GA: generation 4100 – TMT = 5.742609
#     GA: generation 4150 – TMT = 5.742609
#     GA: generation 4200 – TMT = 5.567892
#     GA: generation 4250 – TMT = 5.567892
#     GA: generation 4300 – TMT = 5.567892
#     GA: generation 4350 – TMT = 5.483474
#     GA: generation 4400 – TMT = 5.483474
#     GA: generation 4450 – TMT = 5.483474
#     GA: generation 4500 – TMT = 5.138285
#     GA: generation 4550 – TMT = 5.138285
#     GA: generation 4600 – TMT = 4.825839
#     GA: generation 4650 – TMT = 4.825839
#     GA: generation 4700 – TMT = 4.825839
#     GA: generation 4750 – TMT = 4.825839
#     GA: generation 4800 – TMT = 4.706421
#     GA: generation 4850 – TMT = 4.616436
#     GA: generation 4900 – TMT = 4.272053
#     GA: generation 4950 – TMT = 4.272053
#     GA: generation 5000 – TMT = 4.272053
#     GA: generation 5050 – TMT = 4.272053
#     GA: generation 5100 – TMT = 4.272053
#     GA: generation 5150 – TMT = 4.272053
#     GA: generation 5200 – TMT = 4.272053
#     GA: generation 5250 – TMT = 4.272053
#     GA: generation 5300 – TMT = 4.272053
#     GA: generation 5350 – TMT = 4.272053
#     GA: generation 5400 – TMT = 4.272053
#     GA: generation 5450 – TMT = 4.272053
#     GA: generation 5500 – TMT = 4.272053
#     GA: generation 5550 – TMT = 4.272053
#     GA: generation 5600 – TMT = 4.272053
#     GA: generation 5650 – TMT = 4.272053
#     GA: generation 5700 – TMT = 4.272053
#     GA: generation 5750 – TMT = 4.272053
#     GA: generation 5800 – TMT = 4.071954
#     GA: generation 5850 – TMT = 3.758956
#     GA: generation 5900 – TMT = 3.758956
#     GA: generation 5950 – TMT = 3.614346
#     GA: generation 6000 – TMT = 3.614346
#     GA: generation 6050 – TMT = 3.614346
#     GA: generation 6100 – TMT = 3.614346
#     GA: generation 6150 – TMT = 3.614346
#     GA: generation 6200 – TMT = 3.614346
#     GA: generation 6250 – TMT = 3.614346
#     GA: generation 6300 – TMT = 3.614346
#     GA: generation 6350 – TMT = 3.511106
#     GA: generation 6400 – TMT = 3.473139
#     GA: generation 6450 – TMT = 3.473139
#     GA: generation 6500 – TMT = 3.473139
#     GA: generation 6550 – TMT = 3.473139
#     GA: generation 6600 – TMT = 3.473139
#     GA: generation 6650 – TMT = 3.473139
#     GA: generation 6700 – TMT = 3.292926
#     GA: generation 6750 – TMT = 3.292926
#     GA: generation 6800 – TMT = 3.292926
#     GA: generation 6850 – TMT = 2.661243
#     GA: generation 6900 – TMT = 2.661243
#     GA: generation 6950 – TMT = 2.661243
#     GA: generation 7000 – TMT = 2.525771
#     GA: generation 7050 – TMT = 2.525771
#     GA: generation 7100 – TMT = 2.525771
#     GA: generation 7150 – TMT = 2.525771
#     GA: generation 7200 – TMT = 2.525771
#     GA: generation 7250 – TMT = 2.525771
#     GA: generation 7300 – TMT = 2.525771
#     GA: generation 7350 – TMT = 2.525771
#     GA: generation 7400 – TMT = 2.525771
#     GA: generation 7450 – TMT = 2.525771
#     GA: generation 7500 – TMT = 2.525771
#     GA: generation 7550 – TMT = 2.525771
#     GA: generation 7600 – TMT = 2.525771
#     GA: generation 7650 – TMT = 2.429930
#     GA: generation 7700 – TMT = 2.429930
#     GA: generation 7750 – TMT = 2.429930
#     GA: generation 7800 – TMT = 2.429930
#     GA: generation 7850 – TMT = 2.429930
#     GA: generation 7900 – TMT = 2.429930
#     GA: generation 7950 – TMT = 2.429930
#     GA: generation 8000 – TMT = 2.429930
#     GA: generation 8050 – TMT = 2.429930
#     GA: generation 8100 – TMT = 2.271243
#     GA: generation 8150 – TMT = 2.271243
#     GA: generation 8200 – TMT = 2.271243
#     GA: generation 8250 – TMT = 2.271243
#     GA: generation 8300 – TMT = 2.271243
#     GA: generation 8350 – TMT = 2.271243
#     GA: generation 8400 – TMT = 2.271243
#     GA: generation 8450 – TMT = 2.271243
#     GA: generation 8500 – TMT = 2.164170
#     GA: generation 8550 – TMT = 2.164170
#     GA: generation 8600 – TMT = 2.136396
#     GA: generation 8650 – TMT = 2.136396
#     GA: generation 8700 – TMT = 2.136396
#     GA: generation 8750 – TMT = 2.136396
#     GA: generation 8800 – TMT = 1.978842
#     GA: generation 8850 – TMT = 1.978842
#     GA: generation 8900 – TMT = 1.978842
#     GA: generation 8950 – TMT = 1.978842
#     GA: generation 9000 – TMT = 1.978842
#     GA: generation 9050 – TMT = 1.978842
#     GA: generation 9100 – TMT = 1.978842
#     GA: generation 9150 – TMT = 1.978842
#     GA: generation 9200 – TMT = 1.978842
#     GA: generation 9250 – TMT = 1.675313
#     GA: generation 9300 – TMT = 1.675313
#     GA: generation 9350 – TMT = 1.675313
#     GA: generation 9400 – TMT = 1.562257
#     GA: generation 9450 – TMT = 1.562257
#     GA: generation 9500 – TMT = 1.562257
#     GA: generation 9550 – TMT = 1.562257
#     GA: generation 9600 – TMT = 1.562257
#     GA: generation 9650 – TMT = 1.562257
#     GA: generation 9700 – TMT = 1.562257
#     GA: generation 9750 – TMT = 1.553030
#     GA: generation 9800 – TMT = 1.553030
#     GA: generation 9850 – TMT = 1.553030
#     GA: generation 9900 – TMT = 1.553030
#     GA: generation 9950 – TMT = 1.553030
#     GA: generation 10000 – TMT = 1.553030
#     GA: generation 10050 – TMT = 1.521862
#     GA: generation 10100 – TMT = 1.474059
#     GA: generation 10150 – TMT = 1.474059
#     GA: generation 10200 – TMT = 1.474059
#     GA: generation 10250 – TMT = 1.474059
#     GA: generation 10300 – TMT = 1.474059
#     GA: generation 10350 – TMT = 1.474059
#     GA: generation 10400 – TMT = 1.474059
#     GA: generation 10450 – TMT = 1.474059
#     GA: generation 10500 – TMT = 1.474059
#     GA: generation 10550 – TMT = 1.432764
#     GA: generation 10600 – TMT = 1.432764
#     GA: generation 10650 – TMT = 1.432764
#     GA: generation 10700 – TMT = 1.432764
#     GA: generation 10750 – TMT = 1.432764
#     GA: generation 10800 – TMT = 1.432764
#     GA: generation 10850 – TMT = 1.432764
#     GA: generation 10900 – TMT = 1.432764
#     GA: generation 10950 – TMT = 1.432764
#     GA: generation 11000 – TMT = 1.432764
#     GA: generation 11050 – TMT = 1.432764
#     GA: generation 11100 – TMT = 1.418144
#     GA: generation 11150 – TMT = 1.362081
#     GA: generation 11200 – TMT = 1.354086
#     GA: generation 11250 – TMT = 1.333491
#     GA: generation 11300 – TMT = 1.333491
#     GA: generation 11350 – TMT = 1.333491
#     GA: generation 11400 – TMT = 1.329468
#     GA: generation 11450 – TMT = 1.323354
#     GA: generation 11500 – TMT = 1.323354
#     GA: generation 11550 – TMT = 1.291044
#     GA: generation 11600 – TMT = 1.172145
#     GA: generation 11650 – TMT = 1.172145
#     GA: generation 11700 – TMT = 1.172145
#     GA: generation 11750 – TMT = 1.172145
#     GA: generation 11800 – TMT = 1.152913
#     GA: generation 11850 – TMT = 1.152913
#     GA: generation 11900 – TMT = 1.152913
#     GA: generation 11950 – TMT = 1.152913
#     GA: generation 12000 – TMT = 1.152913
#     GA: generation 12050 – TMT = 1.152913
#     GA: generation 12100 – TMT = 1.152913
#     GA: generation 12150 – TMT = 1.152913
#     GA: generation 12200 – TMT = 1.152913
#     GA: generation 12250 – TMT = 1.152913
#     GA: generation 12300 – TMT = 1.152913
#     GA: generation 12350 – TMT = 1.016038
#     GA: generation 12400 – TMT = 1.016038
#     GA: generation 12450 – TMT = 1.016038
#     GA: generation 12500 – TMT = 1.016038
#     GA: generation 12550 – TMT = 1.016038
#     GA: generation 12600 – TMT = 1.016038
#     GA: generation 12650 – TMT = 1.016038
#     GA: generation 12700 – TMT = 1.007035
#     GA: generation 12750 – TMT = 1.007035
#     GA: generation 12800 – TMT = 1.007035
#     GA: generation 12850 – TMT = 1.007035
#     GA: generation 12900 – TMT = 1.007035
#     GA: generation 12950 – TMT = 1.007035
#     GA: generation 13000 – TMT = 1.007035
#     GA: generation 13050 – TMT = 1.007035
#     GA: generation 13100 – TMT = 0.912837
#     GA: generation 13150 – TMT = 0.912837
#     GA: generation 13200 – TMT = 0.912837
#     GA: generation 13250 – TMT = 0.912837
#     GA: generation 13300 – TMT = 0.912837
#     GA: generation 13350 – TMT = 0.912837
#     GA: generation 13400 – TMT = 0.912837
#     GA: generation 13450 – TMT = 0.912837
#     GA: generation 13500 – TMT = 0.912837
#     GA: generation 13550 – TMT = 0.912837
#     GA: generation 13600 – TMT = 0.912837
#     GA: generation 13650 – TMT = 0.912837
#     GA: generation 13700 – TMT = 0.912837
#     GA: generation 13750 – TMT = 0.788845
#     GA: generation 13800 – TMT = 0.788845
#     GA: generation 13850 – TMT = 0.788845
#     GA: generation 13900 – TMT = 0.788845
#     GA: generation 13950 – TMT = 0.788845
#     GA: generation 14000 – TMT = 0.788845
#     GA: generation 14050 – TMT = 0.788845
#     GA: generation 14100 – TMT = 0.788845
#     GA: generation 14150 – TMT = 0.788845
#     GA: generation 14200 – TMT = 0.788845
#     GA: generation 14250 – TMT = 0.788845
#     GA: generation 14300 – TMT = 0.788845
#     GA: generation 14350 – TMT = 0.761723
#     GA: generation 14400 – TMT = 0.692988
#     GA: generation 14450 – TMT = 0.692988
#     GA: generation 14500 – TMT = 0.692988
#     GA: generation 14550 – TMT = 0.692988
#     GA: generation 14600 – TMT = 0.692988
#     GA: generation 14650 – TMT = 0.692988
#     GA: generation 14700 – TMT = 0.692988
#     GA: generation 14750 – TMT = 0.692988
#     GA: generation 14800 – TMT = 0.692988
#     GA: generation 14850 – TMT = 0.692988
#     GA: generation 14900 – TMT = 0.692988
#     GA: generation 14950 – TMT = 0.692988
#     GA: generation 15000 – TMT = 0.692988
#     GA: generation 15050 – TMT = 0.685733
#     GA: generation 15100 – TMT = 0.685733
#     GA: generation 15150 – TMT = 0.685733
#     GA: generation 15200 – TMT = 0.685733
#     GA: generation 15250 – TMT = 0.669396
#     GA: generation 15300 – TMT = 0.669396
#     GA: generation 15350 – TMT = 0.669396
#     GA: generation 15400 – TMT = 0.624599
#     GA: generation 15450 – TMT = 0.624599
#     GA: generation 15500 – TMT = 0.624599
#     GA: generation 15550 – TMT = 0.624599
#     GA: generation 15600 – TMT = 0.624599
#     GA: generation 15650 – TMT = 0.624599
#     GA: generation 15700 – TMT = 0.624599
#     GA: generation 15750 – TMT = 0.624599
#     GA: generation 15800 – TMT = 0.624599
#     GA: generation 15850 – TMT = 0.624599
#     GA: generation 15900 – TMT = 0.624599
#     GA: generation 15950 – TMT = 0.624599
#     GA: generation 16000 – TMT = 0.624599
#     GA: generation 16050 – TMT = 0.624599
#     GA: generation 16100 – TMT = 0.624599
#     GA: generation 16150 – TMT = 0.624599
#     GA: generation 16200 – TMT = 0.610569
#     GA: generation 16250 – TMT = 0.610569
#     GA: generation 16300 – TMT = 0.610569
#     GA: generation 16350 – TMT = 0.596154
#     GA: generation 16400 – TMT = 0.596154
#     GA: generation 16450 – TMT = 0.596154
#     GA: generation 16500 – TMT = 0.596154
#     GA: generation 16550 – TMT = 0.596154
#     GA: generation 16600 – TMT = 0.596154
#     GA: generation 16650 – TMT = 0.596154
#     GA: generation 16700 – TMT = 0.596154
#     GA: generation 16750 – TMT = 0.528742
#     GA: generation 16800 – TMT = 0.528742
#     GA: generation 16850 – TMT = 0.528742
#     GA: generation 16900 – TMT = 0.528742
#     GA: generation 16950 – TMT = 0.528742
#     GA: generation 17000 – TMT = 0.528742
#     GA: generation 17050 – TMT = 0.528742
#     GA: generation 17100 – TMT = 0.528742
#     GA: generation 17150 – TMT = 0.528742
#     GA: generation 17200 – TMT = 0.528742
#     GA: generation 17250 – TMT = 0.528742
#     GA: generation 17300 – TMT = 0.528742
#     GA: generation 17350 – TMT = 0.528742
#     GA: generation 17400 – TMT = 0.528742
#     GA: generation 17450 – TMT = 0.457206
#     GA: generation 17500 – TMT = 0.457206
#     GA: generation 17550 – TMT = 0.457206
#     GA: generation 17600 – TMT = 0.457206
#     GA: generation 17650 – TMT = 0.457206
#     GA: generation 17700 – TMT = 0.457206
#     GA: generation 17750 – TMT = 0.457206
#     GA: generation 17800 – TMT = 0.457206
#     GA: generation 17850 – TMT = 0.457206
#     GA: generation 17900 – TMT = 0.457206
#     GA: generation 17950 – TMT = 0.457206
#     GA: generation 18000 – TMT = 0.457206
#     GA: generation 18050 – TMT = 0.457206
#     GA: generation 18100 – TMT = 0.457206
#     GA: generation 18150 – TMT = 0.457206
#     GA: generation 18200 – TMT = 0.457206
#     GA: generation 18250 – TMT = 0.457206
#     GA: generation 18300 – TMT = 0.457206
#     GA: generation 18350 – TMT = 0.457206
#     GA: generation 18400 – TMT = 0.457206
#     GA: generation 18450 – TMT = 0.457206
#     GA: generation 18500 – TMT = 0.457206
#     GA: generation 18550 – TMT = 0.457206
#     GA: generation 18600 – TMT = 0.457206
#     GA: generation 18650 – TMT = 0.457206
#     GA: generation 18700 – TMT = 0.449764
#     GA: generation 18750 – TMT = 0.449764
#     GA: generation 18800 – TMT = 0.449764
#     GA: generation 18850 – TMT = 0.449764
#     GA: generation 18900 – TMT = 0.449764
#     GA: generation 18950 – TMT = 0.449764
#     GA: generation 19000 – TMT = 0.449764
#     GA: generation 19050 – TMT = 0.449764
#     GA: generation 19100 – TMT = 0.449764
#     GA: generation 19150 – TMT = 0.449764
#     GA: generation 19200 – TMT = 0.449764
#     GA: generation 19250 – TMT = 0.449764
#     GA: generation 19300 – TMT = 0.449764
#     GA: generation 19350 – TMT = 0.449764
#     GA: generation 19400 – TMT = 0.449764
#     GA: generation 19450 – TMT = 0.449764
#     GA: generation 19500 – TMT = 0.449764
#     GA: generation 19550 – TMT = 0.449764
#     GA: generation 19600 – TMT = 0.449764
#     GA: generation 19650 – TMT = 0.387694
#     GA: generation 19700 – TMT = 0.387694
#     GA: generation 19750 – TMT = 0.387694
#     GA: generation 19800 – TMT = 0.363715
#     GA: generation 19850 – TMT = 0.363715
#     GA: generation 19900 – TMT = 0.363715
#     GA: generation 19950 – TMT = 0.363715
#     GA: generation 20000 – TMT = 0.363715
#     GA: generation 20050 – TMT = 0.363715
#     GA: generation 20100 – TMT = 0.363715
#     GA: generation 20150 – TMT = 0.363715
#     GA: generation 20200 – TMT = 0.363715
#     GA: generation 20250 – TMT = 0.363715
#     GA: generation 20300 – TMT = 0.363715
#     GA: generation 20350 – TMT = 0.363715
#     GA: generation 20400 – TMT = 0.363715
#     GA: generation 20450 – TMT = 0.363715
#     GA: generation 20500 – TMT = 0.363715
#     GA: generation 20550 – TMT = 0.363715
#     GA: generation 20600 – TMT = 0.363715
#     GA: generation 20650 – TMT = 0.363715
#     GA: generation 20700 – TMT = 0.363715
#     GA: generation 20750 – TMT = 0.363715
#     GA: generation 20800 – TMT = 0.363715
#     GA: generation 20850 – TMT = 0.363715
#     GA: generation 20900 – TMT = 0.363715
#     GA: generation 20950 – TMT = 0.363715
#     GA: generation 21000 – TMT = 0.363715
#     GA: generation 21050 – TMT = 0.342495
#     GA: generation 21100 – TMT = 0.342495
#     GA: generation 21150 – TMT = 0.342495
#     GA: generation 21200 – TMT = 0.342495
#     GA: generation 21250 – TMT = 0.342495
#     GA: generation 21300 – TMT = 0.342495
#     GA: generation 21350 – TMT = 0.342495
#     GA: generation 21400 – TMT = 0.342495
#     GA: generation 21450 – TMT = 0.342495
#     GA: generation 21500 – TMT = 0.342495
#     GA: generation 21550 – TMT = 0.342495
#     GA: generation 21600 – TMT = 0.341022
#     GA: generation 21650 – TMT = 0.341022
#     GA: generation 21700 – TMT = 0.341022
#     GA: generation 21750 – TMT = 0.341022
#     GA: generation 21800 – TMT = 0.341022
#     GA: generation 21850 – TMT = 0.341022
#     GA: generation 21900 – TMT = 0.341022
#     GA: generation 21950 – TMT = 0.341022
#     GA: generation 22000 – TMT = 0.341022
#     GA: generation 22050 – TMT = 0.341022
#     GA: generation 22100 – TMT = 0.341022
#     GA: generation 22150 – TMT = 0.332970
#     GA: generation 22200 – TMT = 0.332970
#     GA: generation 22250 – TMT = 0.332970
#     GA: generation 22300 – TMT = 0.332970
#     GA: generation 22350 – TMT = 0.329924
#     GA: generation 22400 – TMT = 0.329924
#     GA: generation 22450 – TMT = 0.329924
#     GA: generation 22500 – TMT = 0.311749
#     GA: generation 22550 – TMT = 0.311749
#     GA: generation 22600 – TMT = 0.311749
#     GA: generation 22650 – TMT = 0.311749
#     GA: generation 22700 – TMT = 0.311749
#     GA: generation 22750 – TMT = 0.311749
#     GA: generation 22800 – TMT = 0.311749
#     GA: generation 22850 – TMT = 0.311749
#     GA: generation 22900 – TMT = 0.311749
#     GA: generation 22950 – TMT = 0.311749
#     GA: generation 23000 – TMT = 0.311749
#     GA: generation 23050 – TMT = 0.311749
#     GA: generation 23100 – TMT = 0.311749
#     GA: generation 23150 – TMT = 0.311749
#     GA: generation 23200 – TMT = 0.311749
#     GA: generation 23250 – TMT = 0.311749
#     GA: generation 23300 – TMT = 0.311749
#     GA: generation 23350 – TMT = 0.311749
#     GA: generation 23400 – TMT = 0.311749
#     GA: generation 23450 – TMT = 0.304306
#     GA: generation 23500 – TMT = 0.304306
#     GA: generation 23550 – TMT = 0.304306
#     GA: generation 23600 – TMT = 0.304306
#     GA: generation 23650 – TMT = 0.304306
#     GA: generation 23700 – TMT = 0.304306
#     GA: generation 23750 – TMT = 0.304306
#     GA: generation 23800 – TMT = 0.304306
#     GA: generation 23850 – TMT = 0.304306
#     GA: generation 23900 – TMT = 0.304306
#     GA: generation 23950 – TMT = 0.304306
#     GA: generation 24000 – TMT = 0.270350
#     GA: generation 24050 – TMT = 0.270350
#     GA: generation 24100 – TMT = 0.270350
#     GA: generation 24150 – TMT = 0.270350
#     GA: generation 24200 – TMT = 0.270350
#     GA: generation 24250 – TMT = 0.270350
#     GA: generation 24300 – TMT = 0.270350
#     GA: generation 24350 – TMT = 0.270350
#     GA: generation 24400 – TMT = 0.270350
#     GA: generation 24450 – TMT = 0.270350
#     GA: generation 24500 – TMT = 0.270350
#     GA: generation 24550 – TMT = 0.270350
#     GA: generation 24600 – TMT = 0.270350
#     GA: generation 24650 – TMT = 0.270350
#     GA: generation 24700 – TMT = 0.262362
#     GA: generation 24750 – TMT = 0.156898
#     GA: generation 24800 – TMT = 0.156898
#     GA: generation 24850 – TMT = 0.156898
#     GA: generation 24900 – TMT = 0.156898
#     GA: generation 24950 – TMT = 0.156898
#     GA: generation 25000 – TMT = 0.156898
#     GA: generation 25050 – TMT = 0.156898
#     GA: generation 25100 – TMT = 0.156898
#     GA: generation 25150 – TMT = 0.156898
#     GA: generation 25200 – TMT = 0.156898
#     GA: generation 25250 – TMT = 0.156898
#     GA: generation 25300 – TMT = 0.156898
#     GA: generation 25350 – TMT = 0.156898
#     GA: generation 25400 – TMT = 0.156898
#     GA: generation 25450 – TMT = 0.156898
#     GA: generation 25500 – TMT = 0.156898
#     GA: generation 25550 – TMT = 0.156898
#     GA: generation 25600 – TMT = 0.156898
#     GA: generation 25650 – TMT = 0.156898
#     GA: generation 25700 – TMT = 0.156898
#     GA: generation 25750 – TMT = 0.156898
#     GA: generation 25800 – TMT = 0.156898
#     GA: generation 25850 – TMT = 0.156898
#     GA: generation 25900 – TMT = 0.156898
#     GA: generation 25950 – TMT = 0.156898
#     GA: generation 26000 – TMT = 0.156898
#     GA: generation 26050 – TMT = 0.156898
#     GA: generation 26100 – TMT = 0.156898
#     GA: generation 26150 – TMT = 0.156898
#     GA: generation 26200 – TMT = 0.156898
#     GA: generation 26250 – TMT = 0.156898
#     GA: generation 26300 – TMT = 0.156898
#     GA: generation 26350 – TMT = 0.156898
#     GA: generation 26400 – TMT = 0.156898
#     GA: generation 26450 – TMT = 0.156898
#     GA: generation 26500 – TMT = 0.156898
#     GA: generation 26550 – TMT = 0.156898
#     GA: generation 26600 – TMT = 0.156898
#     GA: generation 26650 – TMT = 0.156898
#     GA: generation 26700 – TMT = 0.156898
#     GA: generation 26750 – TMT = 0.156898
#     GA: generation 26800 – TMT = 0.156898
#     GA: generation 26850 – TMT = 0.156898
#     GA: generation 26900 – TMT = 0.156898
#     GA: generation 26950 – TMT = 0.156898
#     GA: generation 27000 – TMT = 0.156898
#     GA: generation 27050 – TMT = 0.156898
#     GA: generation 27100 – TMT = 0.148926
#     GA: generation 27150 – TMT = 0.148926
#     GA: generation 27200 – TMT = 0.148926
#     GA: generation 27250 – TMT = 0.148926
#     GA: generation 27300 – TMT = 0.148926
#     GA: generation 27350 – TMT = 0.148926
#     GA: generation 27400 – TMT = 0.148926
#     GA: generation 27450 – TMT = 0.148926
#     GA: generation 27500 – TMT = 0.148926
#     GA: generation 27550 – TMT = 0.148926
#     GA: generation 27600 – TMT = 0.148926
#     GA: generation 27650 – TMT = 0.148926
#     GA: generation 27700 – TMT = 0.148926
#     GA: generation 27750 – TMT = 0.148926
#     GA: generation 27800 – TMT = 0.148926
#     GA: generation 27850 – TMT = 0.148926
#     GA: generation 27900 – TMT = 0.148926
#     GA: generation 27950 – TMT = 0.148926
#     GA: generation 28000 – TMT = 0.148926
#     GA: generation 28050 – TMT = 0.114408
#     GA: generation 28100 – TMT = 0.114408
#     GA: generation 28150 – TMT = 0.114408
#     GA: generation 28200 – TMT = 0.114408
#     GA: generation 28250 – TMT = 0.114408
#     GA: generation 28300 – TMT = 0.114408
#     GA: generation 28350 – TMT = 0.114408
#     GA: generation 28400 – TMT = 0.114408
#     GA: generation 28450 – TMT = 0.114408
#     GA: generation 28500 – TMT = 0.114408
#     GA: generation 28550 – TMT = 0.114408
#     GA: generation 28600 – TMT = 0.114408
#     GA: generation 28650 – TMT = 0.114408
#     GA: generation 28700 – TMT = 0.114408
#     GA: generation 28750 – TMT = 0.114408
#     GA: generation 28800 – TMT = 0.114408
#     GA: generation 28850 – TMT = 0.114408
#     GA: generation 28900 – TMT = 0.114408
#     GA: generation 28950 – TMT = 0.114408
#     GA: generation 29000 – TMT = 0.114408
#     GA: generation 29050 – TMT = 0.114408
#     GA: generation 29100 – TMT = 0.114408
#     GA: generation 29150 – TMT = 0.114408
#     GA: generation 29200 – TMT = 0.114408
#     GA: generation 29250 – TMT = 0.114408
#     GA: generation 29300 – TMT = 0.114408
#     GA: generation 29350 – TMT = 0.090446
#     GA: generation 29400 – TMT = 0.090446
#     GA: generation 29450 – TMT = 0.090446
#     GA: generation 29500 – TMT = 0.090446
#     GA: generation 29550 – TMT = 0.090446
#     GA: generation 29600 – TMT = 0.090446
#     GA: generation 29650 – TMT = 0.090446
#     GA: generation 29700 – TMT = 0.090446
#     GA: generation 29750 – TMT = 0.090446
#     GA: generation 29800 – TMT = 0.090446
#     GA: generation 29850 – TMT = 0.090446
#     GA: generation 29900 – TMT = 0.090446
#     GA: generation 29950 – TMT = 0.043788
#     GA: generation 30000 – TMT = 0.043788
#     GA: generation 30050 – TMT = 0.043788
#     GA: generation 30100 – TMT = 0.043788
#     GA: generation 30150 – TMT = 0.043788
#     GA: generation 30200 – TMT = 0.043788
#     GA: generation 30250 – TMT = 0.043788
#     GA: generation 30300 – TMT = 0.043788
#     GA: generation 30350 – TMT = 0.043788
#     GA: generation 30400 – TMT = 0.043788
#     GA: generation 30450 – TMT = 0.043788
#     GA: generation 30500 – TMT = 0.030136
#     GA: generation 30550 – TMT = 0.030136
#     GA: generation 30600 – TMT = 0.030136
#     GA: generation 30650 – TMT = 0.030136
#     GA: generation 30700 – TMT = 0.030136
#     GA: generation 30750 – TMT = 0.030136
#     GA: generation 30800 – TMT = 0.030136
#     GA: generation 30850 – TMT = 0.030136
#     GA: generation 30900 – TMT = 0.030136
#     GA: generation 30950 – TMT = 0.030136
#     GA: generation 31000 – TMT = 0.030136
#     GA: generation 31050 – TMT = 0.030136
#     GA: generation 31100 – TMT = 0.030136
#     GA: generation 31150 – TMT = 0.030136
#     GA: generation 31200 – TMT = 0.030136
#     GA: generation 31250 – TMT = 0.030136
#     GA: generation 31300 – TMT = 0.030136
#     GA: generation 31350 – TMT = 0.030136
#     GA: generation 31400 – TMT = 0.030136
#     GA: generation 31450 – TMT = 0.030136
#     GA: generation 31500 – TMT = 0.030136
#     GA: generation 31550 – TMT = 0.030136
#     GA: generation 31600 – TMT = 0.030136
#     GA: generation 31650 – TMT = 0.030136
#     GA: generation 31700 – TMT = 0.030136
#     GA: generation 31750 – TMT = 0.030136
#     GA: generation 31800 – TMT = 0.030136
#     GA: generation 31850 – TMT = 0.030136
#     GA: generation 31900 – TMT = 0.030136
#     GA: generation 31950 – TMT = 0.030136
#     GA: generation 32000 – TMT = 0.030136
#     GA: generation 32050 – TMT = 0.030136
#     GA: generation 32100 – TMT = 0.030136
#     GA: generation 32150 – TMT = 0.030136
#     GA: generation 32200 – TMT = 0.030136
#     GA: generation 32250 – TMT = 0.030136
#     GA: generation 32300 – TMT = 0.030136
#     GA: generation 32350 – TMT = 0.030136
#     GA: generation 32400 – TMT = 0.030136
#     GA: generation 32450 – TMT = 0.030136
#     GA: generation 32500 – TMT = 0.030136
#     GA: generation 32550 – TMT = 0.030136
#     GA: generation 32600 – TMT = 0.030136
#     GA: generation 32650 – TMT = 0.030136
#     GA: generation 32700 – TMT = 0.030136
#     GA: generation 32750 – TMT = 0.030136
#     GA: generation 32800 – TMT = 0.030136
#     GA: generation 32850 – TMT = 0.022693
#     GA: generation 32900 – TMT = 0.022693
#     GA: generation 32950 – TMT = 0.022693
#     GA: generation 33000 – TMT = 0.022693
#     GA: generation 33050 – TMT = 0.022693
#     GA: generation 33100 – TMT = 0.022693
#     GA: generation 33150 – TMT = 0.022693
#     GA: generation 33200 – TMT = 0.022693
#     GA: generation 33250 – TMT = 0.022693
#     GA: generation 33300 – TMT = 0.022693
#     GA: generation 33350 – TMT = 0.022693
#     GA: generation 33400 – TMT = 0.022693
#     GA: generation 33450 – TMT = 0.022693
#     GA: generation 33500 – TMT = 0.022693
#     GA: generation 33550 – TMT = 0.022693
#     GA: generation 33600 – TMT = 0.022693
#     GA: generation 33650 – TMT = 0.022693
#     GA: generation 33700 – TMT = 0.022693
#     GA: generation 33750 – TMT = 0.022693
#     GA: generation 33800 – TMT = 0.022693
#     GA: generation 33850 – TMT = 0.022693
#     GA: generation 33900 – TMT = 0.022693
#     GA: generation 33950 – TMT = 0.022693
#     GA: generation 34000 – TMT = 0.022693
#     GA: generation 34050 – TMT = 0.022693
#     GA: generation 34100 – TMT = 0.022693
#     GA: generation 34150 – TMT = 0.022693
#     GA: generation 34200 – TMT = 0.022693
#     GA: generation 34250 – TMT = 0.022693
#     GA: generation 34300 – TMT = 0.022693
#     GA: generation 34350 – TMT = 0.022693
#     GA: generation 34400 – TMT = 0.022693
#     GA: generation 34450 – TMT = 0.022693
#     GA: generation 34500 – TMT = 0.022693
#     GA: generation 34550 – TMT = 0.022693
#     GA: generation 34600 – TMT = 0.022693
#     GA: generation 34650 – TMT = 0.022693
#     GA: generation 34700 – TMT = 0.022693
#     GA: generation 34750 – TMT = 0.022693
#     GA: generation 34800 – TMT = 0.022693
#     GA: generation 34850 – TMT = 0.022693
#     GA: generation 34900 – TMT = 0.022693
#     GA: generation 34950 – TMT = 0.022693
#     GA: generation 35000 – TMT = 0.022693
#     GA: generation 35050 – TMT = 0.022693
#     GA: generation 35100 – TMT = 0.022693
#     GA: generation 35150 – TMT = 0.022693
#     GA: generation 35200 – TMT = 0.022693
#     GA: generation 35250 – TMT = 0.022693
#     GA: generation 35300 – TMT = 0.022693
#     GA: generation 35350 – TMT = 0.015298
#     GA: generation 35400 – TMT = 0.015298
#     GA: generation 35450 – TMT = 0.015298
#     GA: generation 35500 – TMT = 0.015298
#     GA: generation 35550 – TMT = 0.015298
#     GA: generation 35600 – TMT = 0.015298
#     GA: generation 35650 – TMT = 0.015298
#     GA: generation 35700 – TMT = 0.015298
#     GA: generation 35750 – TMT = 0.015298
#     GA: generation 35800 – TMT = 0.015298
#     GA: generation 35850 – TMT = 0.015298
#     GA: generation 35900 – TMT = 0.015298
#     GA: generation 35950 – TMT = 0.015298
#     GA: generation 36000 – TMT = 0.015298
#     GA: generation 36050 – TMT = 0.015298
#     GA: generation 36100 – TMT = 0.015298
#     GA: generation 36150 – TMT = 0.015298
#     GA: generation 36200 – TMT = 0.015298
#     GA: generation 36250 – TMT = 0.007855
#     GA: generation 36300 – TMT = 0.007855
#     GA: generation 36350 – TMT = 0.007855
#     GA: generation 36400 – TMT = 0.007855
#     GA: generation 36450 – TMT = 0.007855
#     GA: generation 36500 – TMT = 0.007855
#     GA: generation 36550 – TMT = 0.007855
#     GA: generation 36600 – TMT = 0.007855
#     GA: generation 36650 – TMT = 0.007855
#     GA: generation 36700 – TMT = 0.007855
#     GA: generation 36750 – TMT = 0.007855
#     GA: generation 36800 – TMT = 0.007855
#     GA: generation 36850 – TMT = 0.007855
#     GA: generation 36900 – TMT = 0.007855
#     GA: generation 36950 – TMT = 0.007855
#     GA: generation 37000 – TMT = 0.007855
#     GA: generation 37050 – TMT = 0.007855
#     GA: generation 37100 – TMT = 0.007855
#     GA: generation 37150 – TMT = 0.007855
#     GA: generation 37200 – TMT = 0.007855
#     GA: generation 37250 – TMT = 0.007855
#     GA: generation 37300 – TMT = 0.007855
#     GA: generation 37350 – TMT = 0.007855
#     GA: generation 37400 – TMT = 0.007855
#     GA: generation 37450 – TMT = 0.006424
#     GA: generation 37500 – TMT = 0.006424
#     GA: generation 37550 – TMT = 0.006424
#     GA: generation 37600 – TMT = 0.006424
#     GA: generation 37650 – TMT = 0.006424
#     GA: generation 37700 – TMT = 0.006424
#     GA: generation 37750 – TMT = 0.006424
#     GA: generation 37800 – TMT = 0.006424
#     GA: generation 37850 – TMT = 0.006424
#     GA: generation 37900 – TMT = 0.006424
#     GA: generation 37950 – TMT = 0.006424
#     GA: generation 38000 – TMT = 0.006424
#     GA: generation 38050 – TMT = 0.006424
#     GA: generation 38100 – TMT = 0.006424
#     GA: generation 38150 – TMT = 0.006424
#     GA: generation 38200 – TMT = 0.006424
#     GA: generation 38250 – TMT = 0.006424
#     GA: generation 38300 – TMT = 0.006424
#     GA: generation 38350 – TMT = 0.006424
#     GA: generation 38400 – TMT = 0.006424
#     GA: generation 38450 – TMT = 0.006424
#     GA: generation 38500 – TMT = 0.006424
#     GA: generation 38550 – TMT = 0.006424
#     GA: generation 38600 – TMT = 0.006424
#     GA: generation 38650 – TMT = 0.006424
#     GA: generation 38700 – TMT = 0.006424
#     GA: generation 38750 – TMT = 0.006424
#     GA: generation 38800 – TMT = 0.006424
#     GA: generation 38850 – TMT = 0.006424
#     GA: generation 38900 – TMT = 0.006424
#     GA: generation 38950 – TMT = 0.006424
#     GA: generation 39000 – TMT = 0.006424
#     GA: generation 39050 – TMT = 0.006424
#     GA: generation 39100 – TMT = 0.006424
#     GA: generation 39150 – TMT = 0.006424
#     GA: generation 39200 – TMT = 0.006424
#     GA: generation 39250 – TMT = 0.006424
#     GA: generation 39300 – TMT = 0.006424
#     GA: generation 39350 – TMT = 0.006424
#     GA: generation 39400 – TMT = 0.006424
#     GA: generation 39450 – TMT = 0.006424
#     GA: generation 39500 – TMT = 0.006424
#     GA: generation 39550 – TMT = 0.006424
#     GA: generation 39600 – TMT = 0.006424
#     GA: generation 39650 – TMT = 0.006424
#     GA: generation 39700 – TMT = 0.006424
#     GA: generation 39750 – TMT = 0.006424
#     GA: generation 39800 – TMT = 0.006424
#     GA: generation 39850 – TMT = 0.006424
#     GA: generation 39900 – TMT = 0.006424
#     GA: generation 39950 – TMT = 0.006424
#     GA: generation 40000 – TMT = 0.006424
#     GA: generation 40050 – TMT = 0.006424
#     GA: generation 40100 – TMT = 0.006424
#     GA: generation 40150 – TMT = 0.006424
#     GA: generation 40200 – TMT = 0.006424
#     GA: generation 40250 – TMT = 0.006424
#     GA: generation 40300 – TMT = 0.006424
#     GA: generation 40350 – TMT = 0.006424
#     GA: generation 40400 – TMT = 0.006424
#     GA: generation 40450 – TMT = 0.006424
#     GA: generation 40500 – TMT = 0.006424
#     GA: generation 40550 – TMT = 0.006424
#     GA: generation 40600 – TMT = 0.006424
#     GA: generation 40650 – TMT = 0.006424
#     GA: generation 40700 – TMT = 0.006424
#     GA: generation 40750 – TMT = 0.006424
#     GA: generation 40800 – TMT = 0.006424
#     GA: generation 40850 – TMT = 0.006424
#     GA: generation 40900 – TMT = 0.006424
#     GA: generation 40950 – TMT = 0.006424
#     GA: generation 41000 – TMT = 0.006424
#     GA: generation 41050 – TMT = 0.006424
#     GA: generation 41100 – TMT = 0.006424
#     GA: generation 41150 – TMT = 0.006424
#     GA: generation 41200 – TMT = 0.006424
#     GA: generation 41250 – TMT = 0.006424
#     GA: generation 41300 – TMT = 0.006424
#     GA: generation 41350 – TMT = 0.006424
#     GA: generation 41400 – TMT = 0.006424
#     GA: generation 41450 – TMT = 0.006424
#     GA: generation 41500 – TMT = 0.006424
#     GA: generation 41550 – TMT = 0.006424
#     GA: generation 41600 – TMT = 0.006424
#     GA: generation 41650 – TMT = 0.006424
#     GA: generation 41700 – TMT = 0.006424
#     GA: generation 41750 – TMT = 0.006424
#     GA: generation 41800 – TMT = 0.006424
#     GA: generation 41850 – TMT = 0.006424
#     GA: generation 41900 – TMT = 0.006424
#     GA: generation 41950 – TMT = 0.006424
#     GA: generation 42000 – TMT = 0.006424
#     GA: generation 42050 – TMT = 0.006424
#     GA: generation 42100 – TMT = 0.006424
#     GA: generation 42150 – TMT = 0.006424
#     GA: generation 42200 – TMT = 0.006424
#     GA: generation 42250 – TMT = 0.006424
#     GA: generation 42300 – TMT = 0.006424
#     GA: generation 42350 – TMT = 0.006424
#     GA: generation 42400 – TMT = 0.006424
#     GA: generation 42450 – TMT = 0.006424
#     GA: generation 42500 – TMT = 0.006424
#     GA: generation 42550 – TMT = 0.006424
#     GA: generation 42600 – TMT = 0.006424
#     GA: generation 42650 – TMT = 0.006424
#     GA: generation 42700 – TMT = 0.006424
#     GA: generation 42750 – TMT = 0.006424
#     GA: generation 42800 – TMT = 0.006424
#     GA: generation 42850 – TMT = 0.006424
#     GA: generation 42900 – TMT = 0.006424
#     GA: generation 42950 – TMT = 0.006424
#     GA: generation 43000 – TMT = 0.006424
#     GA: generation 43050 – TMT = 0.006424
#     GA: generation 43100 – TMT = 0.006424
#     GA: generation 43150 – TMT = 0.006424
#     GA: generation 43200 – TMT = 0.006424
#     GA: generation 43250 – TMT = 0.006424
#     GA: generation 43300 – TMT = 0.003886
#     GA: generation 43350 – TMT = 0.003886
#     GA: generation 43400 – TMT = 0.003886
#     GA: generation 43450 – TMT = 0.003886
#     GA: generation 43500 – TMT = 0.003886
#     GA: generation 43550 – TMT = 0.003886
#     GA: generation 43600 – TMT = 0.003886
#     GA: generation 43650 – TMT = 0.003886
#     GA: generation 43700 – TMT = 0.003886
#     GA: generation 43750 – TMT = 0.003886
#     GA: generation 43800 – TMT = 0.003886
#     GA: generation 43850 – TMT = 0.003886
#     GA: generation 43900 – TMT = 0.003886
#     GA: generation 43950 – TMT = 0.003886
#     GA: generation 44000 – TMT = 0.003886
#     GA: generation 44050 – TMT = 0.003886
#     GA: generation 44100 – TMT = 0.003886
#     GA: generation 44150 – TMT = 0.003886
#     GA: generation 44200 – TMT = 0.003886
#     GA: generation 44250 – TMT = 0.003886
#     GA: generation 44300 – TMT = 0.003886
#     GA: generation 44350 – TMT = 0.003886
#     GA: generation 44400 – TMT = 0.003886
#     GA: generation 44450 – TMT = 0.003886
#     GA: generation 44500 – TMT = 0.003886
#     GA: generation 44550 – TMT = 0.003886
#     GA: generation 44600 – TMT = 0.003886
#     GA: generation 44650 – TMT = 0.003886
#     GA: generation 44700 – TMT = 0.003886
#     GA: generation 44750 – TMT = 0.003886
#     GA: generation 44800 – TMT = 0.003886
#     GA: generation 44850 – TMT = 0.003886
#     GA: generation 44900 – TMT = 0.003886
#     GA: generation 44950 – TMT = 0.003886
#     GA: generation 45000 – TMT = 0.003886
#     GA: generation 45050 – TMT = 0.003886
#     GA: generation 45100 – TMT = 0.003886
#     GA: generation 45150 – TMT = 0.003886
#     GA: generation 45200 – TMT = 0.003886
#     GA: generation 45250 – TMT = 0.003886
#     GA: generation 45300 – TMT = 0.003886
#     GA: generation 45350 – TMT = 0.003886
#     GA: generation 45400 – TMT = 0.003886
#     GA: generation 45450 – TMT = 0.003886
#     GA: generation 45500 – TMT = 0.003886
#     GA: generation 45550 – TMT = 0.003886
#     GA: generation 45600 – TMT = 0.003886
#     GA: generation 45650 – TMT = 0.003886
#     GA: generation 45700 – TMT = 0.003886
#     GA: generation 45750 – TMT = 0.003886
#     GA: generation 45800 – TMT = 0.003886
#     GA: generation 45850 – TMT = 0.003886
#     GA: generation 45900 – TMT = 0.003886
#     GA: generation 45950 – TMT = 0.003886
#     GA: generation 46000 – TMT = 0.003886
#     GA: generation 46050 – TMT = 0.003886
#     GA: generation 46100 – TMT = 0.003886
#     GA: generation 46150 – TMT = 0.003886
#     GA: generation 46200 – TMT = 0.003886
#     GA: generation 46250 – TMT = 0.003886
#     GA: generation 46300 – TMT = 0.003886
#     GA: generation 46350 – TMT = 0.003886
#     GA: generation 46400 – TMT = 0.003886
#     GA: generation 46450 – TMT = 0.003886
#     GA: generation 46500 – TMT = 0.003886
#     GA: generation 46550 – TMT = 0.003886
#     GA: generation 46600 – TMT = 0.003886
#     GA: generation 46650 – TMT = 0.003886
#     GA: generation 46700 – TMT = 0.001325
#     GA: generation 46750 – TMT = 0.001325
#     GA: generation 46800 – TMT = 0.001325
#     GA: generation 46850 – TMT = 0.001325
#     GA: generation 46900 – TMT = 0.001325
#     GA: generation 46950 – TMT = 0.001325
#     GA: generation 47000 – TMT = 0.001325
#     GA: generation 47050 – TMT = 0.001325
#     GA finished. Generations: 47090  – Best TMT = 0.000000
#     Scenario 'scenario_1' optimized. 74 relays updated.
#
# Optimization results saved to: /Users/gustavo/Documents/Projects/TESIS_UNAL/AutoDOC-MG/data/processed/optimized_relay_values_scenario_1_GA.json
# ✅ Final pairs file created: /Users/gustavo/Documents/Projects/TESIS_UNAL/AutoDOC-MG/data/processed/automation_results_scenario_1_optimized.json
# Figure saved: /Users/gustavo/Documents/Projects/TESIS_UNAL/AutoDOC-MG/results/figures/MT_TDS_Pickup_optimized_20251008_112311.png
# Report saved: /Users/gustavo/Documents/Projects/TESIS_UNAL/AutoDOC-MG/results/reports/results_MT_optimized_20251008_112311.txt

# %%
# %% Comparison: Automation vs GA-optimized (metrics and settings)
from pathlib import Path
from datetime import datetime
import json
import math
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

# Inputs/outputs (from earlier paths)
project_root, in_file, opt_file, pairs_out, fig_dir, rep_dir = _paths()
orig_file = in_file  # data/processed/automation_results_scenario_1.json
opt_pairs_file = pairs_out  # data/processed/automation_results_scenario_1_optimized.json
opt_values_file = opt_file  # data/processed/optimized_relay_values_scenario_1_GA.json

# Helpers

def _load_json(path: Path):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

def compute_pair_stats(pairs_list, cti: float):
    total_valid = 0
    coordinated = 0
    uncoordinated = 0
    tmt_sum = 0.0
    deltas = []
    for p in pairs_list:
        m = p.get("main_relay", {})
        b = p.get("backup_relay", {})
        tm = m.get("Time_out", None)
        tb = b.get("Time_out", None)
        if not isinstance(tm, (int, float)) or not isinstance(tb, (int, float)):
            continue
        if tm < 0 or tb < 0:
            continue
        dt = (tb - tm) - cti
        deltas.append(dt)
        total_valid += 1
        if dt >= 0:
            coordinated += 1
        else:
            uncoordinated += 1
            tmt_sum += -dt  # accumulate miscoordination magnitude
    coord_pct = (coordinated / total_valid * 100.0) if total_valid else 0.0
    return {
        "total_pairs": total_valid,
        "coordinated": coordinated,
        "uncoordinated": uncoordinated,
        "coord_pct": coord_pct,
        "tmt": -tmt_sum * -1 + -0  # keep sign clarity; tmt_sum is positive magnitude
    }, deltas

def extract_initial_settings_from_raw(raw_list):
    initial = {}
    for e in raw_list:
        for k in ("main_relay", "backup_relay"):
            r = e.get(k) or {}
            name = str(r.get("relay", "")).strip()
            if not name or name in initial:
                continue
            tds = get_numeric_field(r, ["TDS", "tds"])
            pu  = get_numeric_field(r, ["pick_up", "pickup"])
            if tds is not None or pu is not None:
                initial[name] = {"TDS": tds, "pickup": pu}
    return initial

# Load
raw_pairs = _load_json(Path(orig_file))
opt_pairs = _load_json(Path(opt_pairs_file)) if Path(opt_pairs_file).exists() else []
opt_values = _load_json(Path(opt_values_file)) if Path(opt_values_file).exists() else []
opt_map = (opt_values[0]["relay_values"] if isinstance(opt_values, list) and opt_values else {})

# Metrics before/after
metrics_before, deltas_before = compute_pair_stats(raw_pairs, CTI)
metrics_after, deltas_after = compute_pair_stats(opt_pairs, CTI) if opt_pairs else ({"total_pairs":0,"coordinated":0,"uncoordinated":0,"coord_pct":0.0,"tmt":0.0}, [])

print("Automation vs GA (scenario_1)")
print(f"  Pairs: before={metrics_before['total_pairs']} after={metrics_after['total_pairs']}")
print(f"  Coordination (%): before={metrics_before['coord_pct']:.1f} after={metrics_after['coord_pct']:.1f}")
print(f"  Uncoordinated: before={metrics_before['uncoordinated']} after={metrics_after['uncoordinated']}")
print(f"  TMT (sum of deficits): before={sum([-d for d in deltas_before if d<0]):.6f} after={sum([-d for d in deltas_after if d<0]):.6f}")

# Settings comparison table (if we have initial settings)
initial_settings = extract_initial_settings_from_raw(raw_pairs)
rows = []
for relay_name, init_vals in initial_settings.items():
    ov = opt_map.get(relay_name)
    rows.append({
        "relay": relay_name,
        "TDS_initial": init_vals.get("TDS"),
        "TDS_optimized": (ov or {}).get("TDS"),
        "pickup_initial": init_vals.get("pickup"),
        "pickup_optimized": (ov or {}).get("pickup"),
    })

import pandas as pd
settings_df = pd.DataFrame(rows)
if not settings_df.empty:
    display(settings_df.head(20))
else:
    print("No initial settings found in automation file to compare.")

# Save CSV summary
tables_dir = Path(project_root) / "results" / "tables"
plots_dir = Path(project_root) / "results" / "figures"
tables_dir.mkdir(parents=True, exist_ok=True)
plots_dir.mkdir(parents=True, exist_ok=True)

summary = {
    "coord_pct_before": metrics_before["coord_pct"],
    "coord_pct_after": metrics_after["coord_pct"],
    "uncoord_before": metrics_before["uncoordinated"],
    "uncoord_after": metrics_after["uncoordinated"],
    "tmt_before": sum([-d for d in deltas_before if d<0]),
    "tmt_after": sum([-d for d in deltas_after if d<0])
}
summary_df = pd.DataFrame([summary])
ts = datetime.now().strftime("%Y%m%d_%H%M%S")
summary_path = tables_dir / f"scenario_1_automation_vs_ga_summary_{ts}.csv"
summary_df.to_csv(summary_path, index=False)
print(f"Summary CSV saved: {summary_path}")

# Plots: Δt histograms before/after, settings deltas
f, axs = plt.subplots(1, 2, figsize=(14,5))
axs[0].hist(deltas_before, bins=30, color="#d9534f")
axs[0].axvline(0, color="k", linestyle="--")
axs[0].set_title("Δt distribution – Automation (before)")
axs[0].set_xlabel("Δt = Tb - Tm - CTI (s)")
axs[0].set_ylabel("count")
axs[1].hist(deltas_after, bins=30, color="#5cb85c")
axs[1].axvline(0, color="k", linestyle="--")
axs[1].set_title("Δt distribution – GA optimized (after)")
axs[1].set_xlabel("Δt = Tb - Tm - CTI (s)")
plt.tight_layout()
comp_hist_path = plots_dir / f"scenario_1_dt_hist_before_after_{ts}.png"
f.savefig(comp_hist_path, dpi=300)
plt.close(f)
print(f"Figure saved: {comp_hist_path}")

if not settings_df.empty:
    # TDS and Pickup deltas per relay (bar)
    s_df = settings_df.dropna(subset=["TDS_optimized","pickup_optimized"], how="all").copy()
    if not s_df.empty:
        x = range(len(s_df))
        f2, ax2 = plt.subplots(2, 1, figsize=(14,8), sharex=True)
        ax2[0].bar(x, s_df["TDS_optimized"].values, color="#1f77b4", alpha=0.8, label="TDS optimized")
        ax2[0].bar(x, s_df["TDS_initial"].values, color="#ff7f0e", alpha=0.5, label="TDS initial")
        ax2[0].set_ylabel("TDS")
        ax2[0].set_title("Relay TDS: initial vs optimized")
        ax2[0].legend()
        ax2[0].grid(True, linestyle=":", alpha=0.4)

        ax2[1].bar(x, s_df["pickup_optimized"].values, color="#2ca02c", alpha=0.8, label="Pickup optimized")
        ax2[1].bar(x, s_df["pickup_initial"].values, color="#d62728", alpha=0.5, label="Pickup initial")
        ax2[1].set_ylabel("Pickup (A)")
        ax2[1].set_xlabel("Relay index")
        ax2[1].set_title("Relay pickup: initial vs optimized")
        ax2[1].legend()
        ax2[1].grid(True, linestyle=":", alpha=0.4)

        f2.tight_layout()
        comp_set_path = plots_dir / f"scenario_1_settings_initial_vs_optimized_{ts}.png"
        f2.savefig(comp_set_path, dpi=300)
        plt.close(f2)
        print(f"Figure saved: {comp_set_path}")
    else:
        print("No comparable settings to plot.")
else:
    print("Settings DataFrame empty; skipping settings plots.")
# Out:
# Automation vs GA (scenario_1)
#   Pairs: before=100 after=100
#   Coordination (%): before=12.0 after=100.0
#   Uncoordinated: before=88 after=0
#   TMT (sum of deficits): before=15.854300 after=0.000000
#    relay  TDS_initial  TDS_optimized  pickup_initial  pickup_optimized
# 0    R38      0.05000        0.17661         0.17386           0.28659
# 1    R39      0.08837        0.42170         0.12595           0.28266
# 2    R55      0.11869        0.54305         0.05198           0.09394
# 3    R10      0.15058        0.15376         0.05151           0.84545
# 4     R9      0.15090        0.18489         0.05474           0.95185
# 5    R47      0.14041        0.43921         0.05151           0.19265
# 6    R48      0.14541        0.30144         0.04929           0.39499
# 7    R11      0.13272        0.31995         0.04929           0.31699
# 8    R49      0.13306        0.68122         0.02586           0.08589
# 9    R72      0.15182        0.32792         0.02907           0.40777
# 10   R12      0.16156        0.17031         0.02586           0.71071
# 11   R50      0.16451        0.58737         0.02194           0.16624
# 12   R13      0.16024        0.56419         0.02194           0.17994
# 13   R51      0.17379        0.23787         0.02049           0.60793
# 14   R14      0.05000        0.29703         0.02049           0.32248
# 15   R52      0.05000        0.17374         0.03238           0.28409
# 16   R34      0.11829        0.58870         0.06423           0.16745
# 17   R15      0.16061        0.20128         0.03238           0.81088
# 18   R53      0.14264        0.44351         0.02871           0.11199
# 19   R16      0.15225        0.29614         0.02871           0.55158
# Summary CSV saved: /Users/gustavo/Documents/Projects/TESIS_UNAL/AutoDOC-MG/results/tables/scenario_1_automation_vs_ga_summary_20251008_112312.csv
# Figure saved: /Users/gustavo/Documents/Projects/TESIS_UNAL/AutoDOC-MG/results/figures/scenario_1_dt_hist_before_after_20251008_112312.png
# Figure saved: /Users/gustavo/Documents/Projects/TESIS_UNAL/AutoDOC-MG/results/figures/scenario_1_settings_initial_vs_optimized_20251008_112312.png

# %%
# %% Per-pair comparison: before (automation) vs after (GA)
from pathlib import Path
import pandas as pd
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

project_root, in_file, opt_file, pairs_out, fig_dir, rep_dir = _paths()
orig_pairs = _load_json(Path(in_file))
opt_pairs = _load_json(Path(pairs_out)) if Path(pairs_out).exists() else []

# Build maps by pair key (main-backup relay names)
def _pair_key(entry):
    m = (entry.get("main_relay") or {}).get("relay")
    b = (entry.get("backup_relay") or {}).get("relay")
    return (str(m).strip(), str(b).strip()) if m and b else None

orig_map = {}
for e in orig_pairs:
    k = _pair_key(e)
    if not k:
        continue
    orig_map[k] = e

opt_map_pairs = {}
for e in opt_pairs:
    k = _pair_key(e)
    if not k:
        continue
    opt_map_pairs[k] = e

rows = []
for k, e0 in orig_map.items():
    e1 = opt_map_pairs.get(k)
    m0 = e0.get("main_relay", {}); b0 = e0.get("backup_relay", {})
    tm0 = m0.get("Time_out", None); tb0 = b0.get("Time_out", None)
    dt0 = (tb0 - tm0 - CTI) if isinstance(tm0, (int,float)) and isinstance(tb0, (int,float)) else None

    tm1 = tb1 = dt1 = None
    if e1:
        m1 = e1.get("main_relay", {}); b1 = e1.get("backup_relay", {})
        tm1 = m1.get("Time_out", None); tb1 = b1.get("Time_out", None)
        dt1 = (tb1 - tm1 - CTI) if isinstance(tm1, (int,float)) and isinstance(tb1, (int,float)) else None

    rows.append({
        "Main": k[0],
        "Backup": k[1],
        "Time_main_before": tm0,
        "Time_backup_before": tb0,
        "dt_before": dt0,
        "coord_before": ("YES" if (dt0 is not None and dt0 >= 0) else ("NO" if dt0 is not None else None)),
        "Time_main_after": tm1,
        "Time_backup_after": tb1,
        "dt_after": dt1,
        "coord_after": ("YES" if (dt1 is not None and dt1 >= 0) else ("NO" if dt1 is not None else None)),
        "improvement": (0.0 if (dt0 is None or dt1 is None) else (dt1 - dt0))  # positive => margin improved
    })

pairs_df = pd.DataFrame(rows)
if pairs_df.empty:
    print("No comparable pairs found for per-pair analysis.")
else:
    # Sort by worst dt_before then improvement
    view_df = pairs_df.copy()
    view_df["dt_before"] = pd.to_numeric(view_df["dt_before"], errors="coerce")
    view_df["dt_after"] = pd.to_numeric(view_df["dt_after"], errors="coerce")
    view_df["improvement"] = pd.to_numeric(view_df["improvement"], errors="coerce")
    view_df = view_df.sort_values(["dt_before", "improvement"], ascending=[True, False])
    display(view_df.head(25))

    # Save CSV
    tables_dir = Path(project_root) / "results" / "tables"
    tables_dir.mkdir(parents=True, exist_ok=True)
    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    csv_path = tables_dir / f"scenario_1_per_pair_before_after_{ts}.csv"
    view_df.to_csv(csv_path, index=False)
    print(f"Per-pair CSV saved: {csv_path}")

    # Plot: top 25 worst before and their after dt
    worst = view_df.head(min(25, len(view_df)))
    x = list(range(len(worst)))
    f, ax = plt.subplots(figsize=(14,6))
    ax.bar([i-0.2 for i in x], worst["dt_before"], width=0.4, color="#d9534f", label="dt before")
    ax.bar([i+0.2 for i in x], worst["dt_after"],  width=0.4, color="#5cb85c", label="dt after")
    ax.axhline(0, color="k", linestyle="--")
    ax.set_xticks(x)
    ax.set_xticklabels([f"{r.Main}-{r.Backup}" for r in worst.itertuples()], rotation=45, ha="right")
    ax.set_ylabel("Δt = Tb - Tm - CTI (s)")
    ax.set_title("Top 25 worst pairs (before) and their after Δt")
    ax.legend()
    ax.grid(True, linestyle=":", alpha=0.4)
    plots_dir = Path(project_root) / "results" / "figures"
    plots_dir.mkdir(parents=True, exist_ok=True)
    png_path = plots_dir / f"scenario_1_per_pair_dt_before_after_{ts}.png"
    f.tight_layout()
    f.savefig(png_path, dpi=300)
    plt.close(f)
    print(f"Figure saved: {png_path}")
# Out:
#    Main Backup  Time_main_before  Time_backup_before  dt_before coord_before  \
# 62  R66    R67            0.2699              0.0857    -0.3842           NO
# 86   R7     R6            0.2806              0.0969    -0.3837           NO
# 15  R15    R14            0.2676              0.0945    -0.3731           NO
# 85  R43    R44            0.2732              0.1067    -0.3665           NO
# 69  R30    R29            0.2420              0.0899    -0.3521           NO
# 13  R51    R52            0.2664              0.1217    -0.3447           NO
# 93   R9     R8            0.2566              0.1300    -0.3266           NO
# 91  R45    R46            0.2540              0.1562    -0.2978           NO
# 96  R34     R8            0.2112              0.1335    -0.2777           NO
# 98  R71    R14            0.1676              0.0969    -0.2707           NO
# 99  R71    R52            0.1676              0.1244    -0.2432           NO
# 97  R34    R46            0.2112              0.1748    -0.2364           NO
# 71  R31    R30            0.2701              0.2593    -0.2108           NO
# 72  R68    R69            0.2758              0.2685    -0.2073           NO
# 23  R73    R32            0.2818              0.2826    -0.1992           NO
# 52  R74    R66            0.2838              0.2848    -0.1990           NO
# 51  R74    R28            0.2838              0.2849    -0.1989           NO
# 73  R32    R31            0.2743              0.2759    -0.1984           NO
# 68  R40    R41            0.3142              0.3174    -0.1968           NO
# 49  R61    R74            0.2964              0.3002    -0.1962           NO
# 21  R54    R73            0.2863              0.2917    -0.1946           NO
# 54  R63    R64            0.3113              0.3169    -0.1944           NO
# 2   R10     R9            0.2905              0.2965    -0.1940           NO
# 3   R47    R48            0.3008              0.3071    -0.1937           NO
# 28  R55    R56            0.3338              0.3406    -0.1932           NO
#
#     Time_main_after  Time_backup_after  dt_after coord_after  improvement
# 62         1.198048           1.455825  0.057778         YES     0.441978
# 86         2.176613           2.386985  0.010372         YES     0.394072
# 15         1.716962           2.524187  0.607225         YES     0.980325
# 85         2.688233           3.194779  0.306546         YES     0.673046
# 69         1.723597           1.994979  0.071382         YES     0.423482
# 13         1.682264           1.938164  0.055900         YES     0.400600
# 93         1.163497           2.524516  1.161020         YES     1.487620
# 91         1.789839           2.183056  0.193217         YES     0.491017
# 96         1.422207           2.810503  1.188296         YES     1.465996
# 98         1.447072           2.822675  1.175603         YES     1.446303
# 99         1.447072           2.139185  0.492113         YES     0.735313
# 97         1.422207           2.486154  0.863947         YES     1.100347
# 71         2.111426           2.598952  0.287526         YES     0.498326
# 72         1.705420           1.978462  0.073042         YES     0.280342
# 23         1.825122           2.278903  0.253781         YES     0.452981
# 52         1.148707           1.352922  0.004216         YES     0.203216
# 51         1.148707           2.074824  0.726117         YES     0.925017
# 73         2.035764           2.266307  0.030543         YES     0.228943
# 68         2.205345           2.865784  0.460439         YES     0.657239
# 49         1.035787           1.245747  0.009961         YES     0.206161
# 21         1.813119           2.047727  0.034608         YES     0.229208
# 54         2.092061           2.412909  0.120848         YES     0.315248
# 2          1.517302           2.196265  0.478964         YES     0.672964
# 3          1.635164           1.850039  0.014875         YES     0.208575
# 28         2.031019           3.178110  0.947091         YES     1.140291
# Per-pair CSV saved: /Users/gustavo/Documents/Projects/TESIS_UNAL/AutoDOC-MG/results/tables/scenario_1_per_pair_before_after_20251008_112313.csv
# Figure saved: /Users/gustavo/Documents/Projects/TESIS_UNAL/AutoDOC-MG/results/figures/scenario_1_per_pair_dt_before_after_20251008_112313.png

# %%
# %% TMT analysis and complementary figures (scenario_1)
from pathlib import Path
from datetime import datetime
import numpy as np
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

project_root, in_file, opt_file, pairs_out, fig_dir, rep_dir = _paths()
orig_pairs = _load_json(Path(in_file))
opt_pairs = _load_json(Path(pairs_out)) if Path(pairs_out).exists() else []

# Compute deltas again to avoid dependency on previous cells

def _pair_deltas(pairs_list, cti: float):
    deltas = []
    for p in pairs_list:
        m = p.get("main_relay", {})
        b = p.get("backup_relay", {})
        tm = m.get("Time_out")
        tb = b.get("Time_out")
        if isinstance(tm, (int,float)) and isinstance(tb, (int,float)) and tm >= 0 and tb >= 0:
            deltas.append((tb - tm) - cti)
    return deltas

deltas_before = _pair_deltas(orig_pairs, CTI)
deltas_after  = _pair_deltas(opt_pairs, CTI) if opt_pairs else []

# TMT definitions
# Signed TMT (sum of negative dt values) matches the "-15..." observation
TMT_before_signed = float(np.sum([d for d in deltas_before if d < 0.0]))
TMT_after_signed  = float(np.sum([d for d in deltas_after  if d < 0.0])) if deltas_after else 0.0

# Magnitude TMT (sum of deficits as positive values)
TMT_before_mag = float(np.sum([-d for d in deltas_before if d < 0.0]))
TMT_after_mag  = float(np.sum([-d for d in deltas_after  if d < 0.0])) if deltas_after else 0.0

print("TMT analysis (scenario_1)")
print(f"  Signed TMT: before={TMT_before_signed:.6f}  after={TMT_after_signed:.6f}")
print(f"  Magnitude TMT: before={TMT_before_mag:.6f}  after={TMT_after_mag:.6f}")

# Prepare output dir
plots_dir = Path(project_root) / "results" / "figures"
plots_dir.mkdir(parents=True, exist_ok=True)
ts = datetime.now().strftime("%Y%m%d_%H%M%S")

# (1) Bar chart: TMT before vs after (signed)
f1, ax1 = plt.subplots(figsize=(8,5))
ax1.bar(["Before"], [TMT_before_signed], color="#d9534f")
ax1.bar(["After"],  [TMT_after_signed],  color="#5cb85c")
ax1.axhline(0, color="k", linestyle="--")
ax1.set_ylabel("Signed TMT (s)")
ax1.set_title("Total Miscoordination Time – Signed (scenario_1)")
ax1.grid(True, linestyle=":", alpha=0.4)
path1 = plots_dir / f"scenario_1_TMT_signed_before_after_{ts}.png"
f1.tight_layout(); f1.savefig(path1, dpi=300); plt.close(f1)
print(f"Figure saved: {path1}")

# (2) Bar chart: TMT before vs after (magnitude)
f2, ax2 = plt.subplots(figsize=(8,5))
ax2.bar(["Before"], [TMT_before_mag], color="#d9534f")
ax2.bar(["After"],  [TMT_after_mag],  color="#5cb85c")
ax2.set_ylabel("TMT (sum of deficits, s)")
ax2.set_title("Total Miscoordination Time – Magnitude (scenario_1)")
ax2.grid(True, linestyle=":", alpha=0.4)
path2 = plots_dir / f"scenario_1_TMT_magnitude_before_after_{ts}.png"
f2.tight_layout(); f2.savefig(path2, dpi=300); plt.close(f2)
print(f"Figure saved: {path2}")

# (3) Cumulative miscoordination curves (sorted deficits)
def _cum_curve(deltas):
    deficits = sorted([-d for d in deltas if d < 0.0], reverse=True)
    csum = np.cumsum(deficits) if deficits else []
    return deficits, csum

def_before, csum_before = _cum_curve(deltas_before)
def_after,  csum_after  = _cum_curve(deltas_after)

f3, ax3 = plt.subplots(figsize=(10,6))
ax3.plot(range(1, len(csum_before)+1), csum_before, "-o", ms=3, label="Before", color="#d9534f")
if len(csum_after):
    ax3.plot(range(1, len(csum_after)+1), csum_after,  "-o", ms=3, label="After",  color="#5cb85c")
ax3.set_xlabel("Top-N worst pairs")
ax3.set_ylabel("Cumulative miscoordination (s)")
ax3.set_title("Cumulative miscoordination – before vs after")
ax3.grid(True, linestyle=":", alpha=0.4)
ax3.legend()
path3 = plots_dir / f"scenario_1_cumulative_miscoordination_{ts}.png"
f3.tight_layout(); f3.savefig(path3, dpi=300); plt.close(f3)
print(f"Figure saved: {path3}")

# (4) Per-pair improvement scatter (dt_before vs dt_after)
# Build aligned pairs where both before and after are available
from collections import defaultdict

def _pair_key(e):
    m = (e.get("main_relay") or {}).get("relay")
    b = (e.get("backup_relay") or {}).get("relay")
    return (str(m).strip(), str(b).strip()) if m and b else None

orig_map = {}
for e in orig_pairs:
    k = _pair_key(e)
    if not k:
        continue
    m = e.get("main_relay", {}); b = e.get("backup_relay", {})
    tm = m.get("Time_out"); tb = b.get("Time_out")
    if isinstance(tm, (int,float)) and isinstance(tb, (int,float)):
        orig_map[k] = (tb - tm) - CTI

after_map = {}
for e in opt_pairs:
    k = _pair_key(e)
    if not k:
        continue
    m = e.get("main_relay", {}); b = e.get("backup_relay", {})
    tm = m.get("Time_out"); tb = b.get("Time_out")
    if isinstance(tm, (int,float)) and isinstance(tb, (int,float)):
        after_map[k] = (tb - tm) - CTI

xy = [(orig_map[k], after_map[k]) for k in orig_map.keys() if k in after_map]
xb = [p[0] for p in xy]; ya = [p[1] for p in xy]

f4, ax4 = plt.subplots(figsize=(7,7))
ax4.scatter(xb, ya, s=12, alpha=0.7)
lims = [min(xb+ya+[0]), max(xb+ya+[0])]
ax4.plot(lims, lims, 'k--', linewidth=1)
ax4.axvline(0, color='k', linestyle=':'); ax4.axhline(0, color='k', linestyle=':')
ax4.set_xlabel("Δt before (s)")
ax4.set_ylabel("Δt after (s)")
ax4.set_title("Per-pair Δt improvement scatter")
ax4.grid(True, linestyle=":", alpha=0.4)
path4 = plots_dir / f"scenario_1_per_pair_scatter_dt_before_after_{ts}.png"
f4.tight_layout(); f4.savefig(path4, dpi=300); plt.close(f4)
print(f"Figure saved: {path4}")

# (5) Overlay histograms of deficit magnitudes before/after
f5, ax5 = plt.subplots(figsize=(10,6))
ax5.hist([-d for d in deltas_before if d < 0.0], bins=30, alpha=0.6, label="Before", color="#d9534f")
if deltas_after:
    ax5.hist([-d for d in deltas_after if d < 0.0],  bins=30, alpha=0.6, label="After",  color="#5cb85c")
ax5.set_xlabel("Miscoordination magnitude (s)")
ax5.set_ylabel("count")
ax5.set_title("Miscoordination magnitude distribution – before vs after")
ax5.legend(); ax5.grid(True, linestyle=":", alpha=0.4)
path5 = plots_dir / f"scenario_1_miscoordination_magnitude_hist_{ts}.png"
f5.tight_layout(); f5.savefig(path5, dpi=300); plt.close(f5)
print(f"Figure saved: {path5}")

# Show figures inline in the notebook
try:
    from IPython.display import Image, display
    for p in [path1, path2, path3, path4, path5]:
        display(Image(filename=str(p)))
except Exception as _e:
    pass
# Out:
# TMT analysis (scenario_1)
#   Signed TMT: before=-15.854300  after=0.000000
#   Magnitude TMT: before=15.854300  after=0.000000
# Figure saved: /Users/gustavo/Documents/Projects/TESIS_UNAL/AutoDOC-MG/results/figures/scenario_1_TMT_signed_before_after_20251008_112314.png
# Figure saved: /Users/gustavo/Documents/Projects/TESIS_UNAL/AutoDOC-MG/results/figures/scenario_1_TMT_magnitude_before_after_20251008_112314.png
# Figure saved: /Users/gustavo/Documents/Projects/TESIS_UNAL/AutoDOC-MG/results/figures/scenario_1_cumulative_miscoordination_20251008_112314.png
# Figure saved: /Users/gustavo/Documents/Projects/TESIS_UNAL/AutoDOC-MG/results/figures/scenario_1_per_pair_scatter_dt_before_after_20251008_112314.png
# Figure saved: /Users/gustavo/Documents/Projects/TESIS_UNAL/AutoDOC-MG/results/figures/scenario_1_miscoordination_magnitude_hist_20251008_112314.png

# %%
# %% Full per-pair comparison (all pairs): slope chart before vs after
from pathlib import Path
from datetime import datetime
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

project_root, in_file, opt_file, pairs_out, fig_dir, rep_dir = _paths()
orig_pairs = _load_json(Path(in_file))
opt_pairs = _load_json(Path(pairs_out)) if Path(pairs_out).exists() else []

# Build aligned per-pair list
def _pair_key(e):
    m = (e.get("main_relay") or {}).get("relay")
    b = (e.get("backup_relay") or {}).get("relay")
    return (str(m).strip(), str(b).strip()) if m and b else None

orig_map = {}
for e in orig_pairs:
    k = _pair_key(e)
    if not k:
        continue
    m = e.get("main_relay", {}); b = e.get("backup_relay", {})
    tm = m.get("Time_out"); tb = b.get("Time_out")
    if isinstance(tm, (int,float)) and isinstance(tb, (int,float)):
        orig_map[k] = (tb - tm) - CTI

after_map = {}
for e in opt_pairs:
    k = _pair_key(e)
    if not k:
        continue
    m = e.get("main_relay", {}); b = e.get("backup_relay", {})
    tm = m.get("Time_out"); tb = b.get("Time_out")
    if isinstance(tm, (int,float)) and isinstance(tb, (int,float)):
        after_map[k] = (tb - tm) - CTI

pairs = []
for k, dtb in orig_map.items():
    if k in after_map:
        dta = after_map[k]
        label = f"{k[0]}–{k[1]}"
        pairs.append((label, dtb, dta))

if not pairs:
    print("No pairs to compare.")
else:
    # Sort by dt_before ascending (worst at bottom for horizontal plot)
    pairs.sort(key=lambda t: t[1])
    labels = [p[0] for p in pairs]
    dt_before = [p[1] for p in pairs]
    dt_after  = [p[2] for p in pairs]

    n = len(pairs)
    height = max(8, int(0.25*n))
    fig, ax = plt.subplots(figsize=(16, height))

    y = list(range(n))
    # Draw connecting lines
    for i in range(n):
        ax.plot([dt_before[i], dt_after[i]], [i, i], color="#b0b0b0", linewidth=1)
    # Points
    ax.scatter(dt_before, y, color="#d9534f", label="Δt before", s=18)
    ax.scatter(dt_after,  y, color="#5cb85c", label="Δt after", s=18)

    ax.axvline(0, color="k", linestyle="--", linewidth=1)
    ax.set_xlabel("Δt = Tb - Tm - CTI (s)")
    ax.set_yticks(y)
    ax.set_yticklabels(labels)
    ax.set_title("Scenario 1 – Per-pair Δt comparison (before vs after)")
    ax.grid(True, axis="x", linestyle=":", alpha=0.4)
    ax.legend(loc="lower right")
    plt.tight_layout()

    plots_dir = Path(project_root) / "results" / "figures"
    plots_dir.mkdir(parents=True, exist_ok=True)
    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    out_path = plots_dir / f"scenario_1_per_pair_slope_before_after_{ts}.png"
    fig.savefig(out_path, dpi=300)
    plt.close(fig)
    print(f"Figure saved: {out_path}")

    # Show inline
    try:
        from IPython.display import Image, display
        display(Image(filename=str(out_path)))
    except Exception:
        pass
# Out:
# Figure saved: /Users/gustavo/Documents/Projects/TESIS_UNAL/AutoDOC-MG/results/figures/scenario_1_per_pair_slope_before_after_20251008_112316.png
